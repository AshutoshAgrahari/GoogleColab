# %% [markdown]
# <a href="https://colab.research.google.com/github/AshutoshAgrahari/GoogleColab/blob/master/Intro_to_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape = [1])])

# %%
model.compile(optimizer="sgd", loss="mean_squared_error")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype=float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype=float)

# %%
print(xs)
print(ys)
# Out:
# [-1.  0.  1.  2.  3.  4.]
# [-3. -1.  1.  3.  5.  7.]

# %%
# Training the Neural Network
model.fit(xs,ys,epochs=500)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# 6/6 [==============================] - 0s 81ms/sample - loss: 15.3833
# Epoch 2/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 12.3452
# Epoch 3/500
# 6/6 [==============================] - 0s 838us/sample - loss: 9.9499
# Epoch 4/500
# 6/6 [==============================] - 0s 705us/sample - loss: 8.0605
# Epoch 5/500
# 6/6 [==============================] - 0s 736us/sample - loss: 6.5693
# Epoch 6/500
# 6/6 [==============================] - 0s 722us/sample - loss: 5.3914
# Epoch 7/500
# 6/6 [==============================] - 0s 579us/sample - loss: 4.4601
# Epoch 8/500
# 6/6 [==============================] - 0s 256us/sample - loss: 3.7229
# Epoch 9/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.981556]]
