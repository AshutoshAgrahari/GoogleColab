# %% [markdown]
# <a href="https://colab.research.google.com/github/AshutoshAgrahari/GoogleColab/blob/master/House_Prices_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### House Prices Prediction
# #### predicting house prices based on a simple, linear equation.

# %% [markdown]
# ###### Importing the libraries

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ######Buiding the dataset

# %%
xs = np.array([2.0,3.0,1.0,4.0,5.0], dtype='float')
ys = np.array([1.5,2.0,1.0,2.5,3.0], dtype='float')

# %% [markdown]
# ######Building the model

# %%
tf.random.set_random_seed(1234)

# %%
model = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])

# %%
model.compile(optimizer="sgd",loss="mean_squared_error")

# %%
# Training Neural Network
model.fit(xs,ys,epochs=1000)
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 0s 51ms/sample - loss: 4.5215
# Epoch 2/1000
# 5/5 [==============================] - 0s 390us/sample - loss: 2.6433
# Epoch 3/1000
# 5/5 [==============================] - 0s 491us/sample - loss: 1.5487
# Epoch 4/1000
# 5/5 [==============================] - 0s 358us/sample - loss: 0.9108
# Epoch 5/1000
# 5/5 [==============================] - 0s 291us/sample - loss: 0.5390
# Epoch 6/1000
# 5/5 [==============================] - 0s 348us/sample - loss: 0.3223
# Epoch 7/1000
# 5/5 [==============================] - 0s 325us/sample - loss: 0.1959
# Epoch 8/1000
# 5/5 [==============================] - 0s 326us/sample - loss: 0.1223
# Epoch 9/1000
# 5/5 [==============================] - 0s 245us/sample - loss: 0.0793
# Epoch 10/1000
# 5/5 [==============================] - 0s 244us/sample - loss: 0.0541
# Epoch 11/1000
# 5/5 [==============================] - 0s 500us/sample - loss: 0.0395
# Epoch 12/1000
# ...

# %%
print(model.predict([7.0]))
# Out:
# [[4.0106487]]
